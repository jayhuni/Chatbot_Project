# %%
import pandas as pd

# %%
df = pd.read_csv('data/팁308 수정 copy.csv')
df
# Out:
#      Unnamed: 0 구분                                                 질문  \
# 0             0  팁  아파트를 매도할때 집 앞에 부동산에만 얘기를 할지동네 부동산에 전부다 얘기를 할지 ...
# 1             1  팁  제꿈이 부동산을 운영하면서 매매도 열심히해드리고 돈도 많이벌고싶은 22살입니다 부동...
# 2             2  팁  사정이 좋지않아서 지금 매수세가 없지만 집을 팔아야하네요ㅜㅜ근처부동산에는 전화돌려보...
# 3             3  팁  곧 계약이 다되가서 월세 방을 구해야하는데요이 집 구할때도 부동산 사람이 의도적으로...
# 4             4  팁  반려견이 2마리있는데 부동산을 하루에 15곳도 가봤지만하나같이 집이 없다 또는 집주...
# ..          ... ..                                                ...
# 303         304  팁  이번에 제가 부동산을 직거래 할려고 하는데 계약서는 어떻게 써야할 지 몰라서 부동산...
# 304         305  팁  일반음식점 운영중인데 계약기간 만료전 인수자를 구해 나가려고 합니다. 제가 직접 인...
# 305         306  팁  안녕하세요. 수리수리마하수리12345입니다.최근에 부동산 경매에 관심이 있어 이것저...
# 306         307  팁  아파트나 부동산같은것을 취득한 후에는 취등록세를 언제까지 납부를해야되는건가요??등기...
# 307         308  팁  최근 2년정도 거래없고 3-4년 전에 7-8천에 거래됐었고 공시지가는 4천4백정도인...
#
#                                                     답변
# 0                                  최소3군데가봐야정확한가격이나옵니다.
# ...

# %%
# 결측치 확인
df.isna().sum()
# Out:
# Unnamed: 0    0
# 구분            1
# 질문            1
# 답변            1
# dtype: int64

# %%
# unnamed 컬럼 / 결측치 삭제
df.drop(columns=['Unnamed: 0'], inplace=True)
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# 구분    0
# 질문    0
# 답변    0
# dtype: int64

# %%
df.to_csv('data/팁307_결측수정.csv')

# %%
df
# Out:
#     구분                                                 질문  \
# 0    팁  아파트를 매도할때 집 앞에 부동산에만 얘기를 할지동네 부동산에 전부다 얘기를 할지 ...
# 1    팁  제꿈이 부동산을 운영하면서 매매도 열심히해드리고 돈도 많이벌고싶은 22살입니다 부동...
# 2    팁  사정이 좋지않아서 지금 매수세가 없지만 집을 팔아야하네요ㅜㅜ근처부동산에는 전화돌려보...
# 3    팁  곧 계약이 다되가서 월세 방을 구해야하는데요이 집 구할때도 부동산 사람이 의도적으로...
# 4    팁  반려견이 2마리있는데 부동산을 하루에 15곳도 가봤지만하나같이 집이 없다 또는 집주...
# ..  ..                                                ...
# 303  팁  이번에 제가 부동산을 직거래 할려고 하는데 계약서는 어떻게 써야할 지 몰라서 부동산...
# 304  팁  일반음식점 운영중인데 계약기간 만료전 인수자를 구해 나가려고 합니다. 제가 직접 인...
# 305  팁  안녕하세요. 수리수리마하수리12345입니다.최근에 부동산 경매에 관심이 있어 이것저...
# 306  팁  아파트나 부동산같은것을 취득한 후에는 취등록세를 언제까지 납부를해야되는건가요??등기...
# 307  팁  최근 2년정도 거래없고 3-4년 전에 7-8천에 거래됐었고 공시지가는 4천4백정도인...
#
#                                                     답변
# 0                                  최소3군데가봐야정확한가격이나옵니다.
# 1    부동산을 운영하고 돈을 버는 것은 나이와는 전혀 상관이 없다고 해야겠지요 .일단 부...
# 2    일단1. 동네 부동산에 최대한 많이 내놓으세요.2. 가격을 아까우시겠지만 최대한 낮...
# ...
